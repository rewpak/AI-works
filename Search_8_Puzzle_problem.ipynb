# %% [markdown]
# <a href="https://colab.research.google.com/github/rewpak/AI-works/blob/main/Search_8_Puzzle_problem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 2. Search
# # Task 2.2 8-Puzzy Problem
# ## Problem Descriptions
# We are given a 3x3 grid with numbered tiles from 1 to 8 and blank space. The tiles are randomly arranged. The aim of this puzzle is to rearange the numbered tiles with the minimal number of movements, so they are in numerically order and the gap at the end.
#
# ![picture](https://drive.google.com/uc?export=view&id=1S8Uzi0LfwMU88XJNjX58xhss9kOIIBlJ)
#
# The formalution of 8-puzzle is follow:
#
#
# 1.   **State**: The state of a numbered tile shows where it is on a 3x3 grid with numbers 1-8 and 'E' for the empty space. We represent this with dashes in a single string to see what the puzzle looks like at any point.
#
# 2. **Action**: It is sipmler to move the blabk tile in the four direction: up, down, left, right. we also need to check the boundary conditions to decide which of the four moves are valid for a given state.
#
# 3. **Goal test**: We want to check if the current arrangement matches the final goal state of "E-1-2-3-4-5-6-7-8"
#
# 4. **Path Cost**: The cost is the count of moves it takes to solve the puzzle. Each step is one move.
# ## Implementation and Results

# %%
# !pip install simpleai
from simpleai.search import SearchProblem, astar, greedy, breadth_first, depth_first
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.4/94.4 kB 1.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for simpleai: filename=simpleai-0.8.3-py3-none-any.whl size=100984 sha256=87d827af04ce6610f355e588a3939cd2fa3c5180544074c496c74bd6fa2449ea
#   Stored in directory: /root/.cache/pip/wheels/91/0c/38/421d7910e7bc59b97fc54f490808bdb1097607d83d1a592865
# Successfully built simpleai
# ...

# %%
# Class containing methods to solve the puzzle
class PuzzleSolver(SearchProblem):
      # Action method to get the list of the possible numbers that can be moved in to the empty space
      def actions(self, cur_state):
          rows = string_to_list(cur_state)
          row_empty, col_empty = get_location(rows, 'E')

          actions = []
          if row_empty > 0: actions.append(rows[row_empty - 1][col_empty])
          if row_empty < 2: actions.append(rows[row_empty + 1][col_empty])
          if col_empty > 0: actions.append(rows[row_empty][col_empty - 1])
          if col_empty < 2: actions.append(rows[row_empty][col_empty + 1])
          return actions

      # Return the resulting state after moving a piece to the empty space
      def result(self, state, action):
          rows = string_to_list(state)
          row_empty, col_empty = get_location(rows, 'E')
          row_new, col_new = get_location(rows, action)
          rows[row_empty][col_empty], rows[row_new][col_new] = rows[row_new][col_new], rows[row_empty][col_empty]
          return list_to_string(rows)

      # Returns true if a state is the goal state
      def is_goal(self, state):
          return state == GOAL

      # # Returns an estimate of the distance from a state to the goal using the manhattan distance
      def heuristic(self, state):
           rows = string_to_list(state)
           distance = 0
           for number in '12345678E':
               row_new, col_new = get_location(rows, number)
               row_new_goal, col_new_goal = goal_positions[number]
               distance += abs(row_new - row_new_goal) + abs(col_new - col_new_goal)
           return distance

      # Returns the number of misplaced tiles
      #def heuristic(self, state):
          #rows = string_to_list(state)
          #goal = string_to_list(GOAL)
          #distance = sum([rows[i] != goal[i] for i in range(len(rows))]) - 1
          #return distance

# %%
import time
start_time = time.process_time()
# Convert list to string
def list_to_string(input_list):
    return '\n'.join(['-'.join(x) for x in input_list])

# Convert string to list
def string_to_list(input_string):
    return [x.split('-') for x in input_string.split('\n')]

# Find the 2D location of the input element
def get_location(rows, input_element):
    for i, row in enumerate(rows):
        for j, item in enumerate(row):
            if item == input_element:
                return i, j

# Final result that we want to achieve
GOAL = '''\
E-1-2
3-4-5
6-7-8'''

# Starting point - solution depth = 26
INITIAL = '''\
7-2-4
5-E-6
8-3-1'''

# Starting point - solution depth = 8
#INITIAL = '''\
#1-4-2
#5-E-8
#3-6-7'''

# Starting point - solution depth = 4
#INITIAL = '''\
#1-4-2
#3-5-8
#6-7-E'''

# Create a cache for the goal position of each piece
goal_positions = {}
rows_goal = string_to_list(GOAL)
for number in '12345678E':
    goal_positions[number] = get_location(rows_goal, number)

# Create the A* solver object
result = astar(PuzzleSolver(INITIAL))
# result = greedy(PuzzleSolver(INITIAL))
# result = breadth_first(PuzzleSolver(INITIAL))
# result = depth_first(PuzzleSolver(INITIAL))

# Print the results
for i, (action, state) in enumerate(result.path()):
    print()
    if action == None:
        print('Initial configuration')
    else:
        print('Step %s: After moving %s into the empty space' %(i, action))
    print(state)
print('Goal achieved!')
end_time = time.process_time()
elapsed_time = end_time - start_time
print(f"Runtime: {elapsed_time} seconds")
# Out:
# Initial configuration
# 7-2-4
# 5-E-6
# 8-3-1
#
# Step 1: After moving 5 into the empty space
# 7-2-4
# E-5-6
# 8-3-1
#
# Step 2: After moving 7 into the empty space
# E-2-4
# 7-5-6
# 8-3-1
#
# Step 3: After moving 2 into the empty space
# 2-E-4
# 7-5-6
# 8-3-1
#
# Step 4: After moving 5 into the empty space
# 2-5-4
# 7-E-6
# 8-3-1
#
# Step 5: After moving 6 into the empty space
# 2-5-4
# 7-6-E
# 8-3-1
#
# Step 6: After moving 1 into the empty space
# 2-5-4
# 7-6-1
# 8-3-E
#
# Step 7: After moving 3 into the empty space
# 2-5-4
# 7-6-1
# 8-E-3
#
# Step 8: After moving 8 into the empty space
# 2-5-4
# 7-6-1
# E-8-3
#
# Step 9: After moving 7 into the empty space
# 2-5-4
# E-6-1
# 7-8-3
#
# Step 10: After moving 6 into the empty space
# 2-5-4
# 6-E-1
# 7-8-3
#
# Step 11: After moving 1 into the empty space
# 2-5-4
# 6-1-E
# 7-8-3
#
# Step 12: After moving 3 into the empty space
# 2-5-4
# 6-1-3
# 7-8-E
#
# Step 13: After moving 8 into the empty space
# 2-5-4
# 6-1-3
# 7-E-8
#
# ...

# %% [markdown]
# ## Discussions
# **SIMPLE CASE**
#
# In this task we had to implement the A*, greedy, breadth-first and depth-first search to the simple case '1-4-2-3-5-8-6-7-E', the following searches A, greedy and breadth-first were all able to give solution with cost of 4 moves however the depth-first search gave a runtime error.
#
#
# Runtime has the following values:
#
# **Using heuristic with the number of misplaced tiles**
#
# 1.   A* search: 0.000956s
# 2.   Greedy search: 0,000659s
# 3.   Breadth-first: 0.00158s
#
# The fastest search method is Greedy search, the slowest one is Breadth-first.
#
# **Using the heuristic with the sum of distances of tiles from their target positions**
#
# 1.   A* search: 0.00154s
# 2.   Greedy search: 0,00301s
# 3.   Breadth-first: 0.00566s
#
# The fastest search method is A* search, the slowest one is Breadth-first.
#
#
# **DIFFICULT CASE**
#
# In this task we had to implement the A* and greedy search to the difficult case '7-2-4-5-E-6-8-3-1.
#
# **Runtime has the following values:**
#
# Using heuristic with the number of misplaced tiles
#
# 1. A* search: Runtime error
# 2. Greedy search: Runtime error
#
# Using the heuristic with the sum of distances of tiles from their target positions
#
# 1. A* search: **18.223s** and number of movements was 26 movements
# 2. Greedy search: Runtime error
#
# The prime reasons for the run time errors occurring was because either the number of nodes generated in the search went beyond control quickly and therefore lots of memory was taken up and all the RAM was used up or a poor heuristic function was used making it difficult to find the optimal solution efficiently.
